# %%
# data manipulation
import pandas as pd
import numpy as np

# plot
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set(context='paper')

# statistics
from scipy import stats

# scrapping
import urllib.request
from bs4 import BeautifulSoup

# comparing sequences
import difflib

# regex
import re

# counter
from collections import Counter

from sqlalchemy import create_engine

# %%
# import datasets
engine = create_engine('sqlite:///data.db', echo=False)
con = engine.connect()
df_patient = pd.read_sql('select * from patient', con=con)
df_pcr = pd.read_sql('select * from test', con=con)
con.close()

# %% [markdown]
# ## Analyse de forme

# %% [markdown]
# Le dataframe contient des informations sur le lieu de résidence des patients, notamment l'état et le code postal.
# L'Australie est constitué de 8 états, chacun étant défini par une plage de codes postaux (source: [Wikipedia](https://en.wikipedia.org/wiki/Postcodes_in_Australia)):
# - **NSW (New South Wales):** 1000 -> 1999,  2000 -> 2599, 2619 -> 2899, 2921 -> 2999.
# - **ACT (Australian Capital Territory) :** 	0200 -> 0299, 2600 -> 2618, 2900 -> 2920.
# - **VIC (Victoria) :** 3000 -> 3999, 8000 -> 8999.
# - **QLD (Queensland) :** 4000 -> 4999, 9000 -> 9999.
# - **SA (South Australia) :** 5000 -> 5799, 5800 -> 5999.
# - **WA (Western Australia) :** 	6000 -> 6797, 6800 -> 6999.
# - **TAS (Tasmania) :** 7000 -> 7799, 7800 ->7999.
# - **NT (Northern Territory):** 0800 -> 0899, 0900 -> 0999.
#
# Le dataframe fournit également le nom, le prénom, l'age et la date de naissance (au format AAAAMMDD) des patients. Ainsi qu'un numéro téléphone, qui est au format : **0X XXXXXXXX**. Il est constitué d'un code d'accès le '0' puis du code de la zone suivi du numéro local (source : [Wikipedia](https://en.m.wikipedia.org/wiki/Telephone_numbers_in_Australia)).
#
# - **00**: Accès international et d'urgence (voir ci-dessous les détails).
# - **01**: Services téléphoniques alternatifs.
#     - **014**: Téléphones satellites.
#     - **0163**: Numéros de téléavertisseur.
#     - **0198** Numéros de données.
# - **02**: Région du Centre-Est ( NSW , ACT )
# - **03**: Région du Sud-Est ( VIC , TAS )
# - **04**: Services mobiles numériques ( 3G , 4G , 5G et GSM )
# - **0550**: Services de communication indépendants de l'emplacement
# - **07**: Géographie: région du Nord-Est ( QLD )
# - **08**: Région du Centre et de l'Ouest ( SA , NT , WA )
# - **1** Numéros non géographiques
#
#
# Concernant la variable 'suburb', le gouvernement australien fournit des données permettant de faire le lien avec la ou les états correspondants, [GouvAus](https://www.abs.gov.au/websitedbs/D3310114.nsf/home/census).

# %% [markdown]
# ### Correspondance des variables

# %% [markdown]
# Cette partie va permettre d'exploiter des informations provenants de sources différentes mais aussi de méthodes différentes (ex: scrapping pour les codes postaux...)
# Les dictionnaires ainsi créés vont permettre de faire le lien entre :
# - Le code de la zone fourni par le numéro de téléphone et les états.
# - Les codes postaux et l'état correspondant.
# - Le nom de la banlieu et les états correspondants

# %%
# dictionnary of states
dict_state = {'nsw': 'New South Wales', 
             'act': 'Australian Capital Territory',
             'vic': 'Victoria',
             'qld': 'Queensland',
             'sa': 'South Australia',
             'wa': 'Western Australia',
             'tas': 'Tasmania',
             'nt': 'Northern Territory'}

# dictionnary of "area" zone
dict_phone_number = {'02': 'nsw act',
                    '03': 'vic tas',
                    '07': 'qld',
                    '08': 'sa nt wa'}

# %%
def scrapping_wikipedia(url):
    """
    This function find the poscode range by state from wikipedia.
    
    url = 'https://en.wikipedia.org/wiki/Postcodes_in_Australia'
    """    
    # open the url using urllib.request and put the HTML into the page variable
    page = urllib.request.urlopen(url)
    
    # parse the HTML from our URL into the BeautifulSoup parse tree format
    soup = BeautifulSoup(page, "lxml")
    
    # use the 'find_all' function to bring back all instances of the 'table' tag in the HTML and store in 'all_tables' variable
    all_tables=soup.find_all("table")
    
    # find the right table
    right_table=soup.find('table', class_='wikitable')
    
    # list of elements by column
    A=[]
    B=[]
    C=[]
    
    for row in right_table.findAll('tr'): # find rows
        cells=row.findAll('td') # find data
        if len(cells)==3: # 3 is the number of columns
            #append cell value
            A.append(cells[0].find(text=True)) 
            B.append(cells[1].find(text=True).lower()) 
            C.append(cells[2].get_text(separator=' ')) 
    
    # create the dataframe from table
    df=pd.DataFrame(A,columns=['State'])
    df['Abbreviation']=B
    df['Postcode range']=C
    
    # postcode range dictionnary
    poscode_range={}
    
    # for each state find the poscode range
    for abb in df.Abbreviation.values:
        poscode_range[abb] = re.findall('[0-9]+', 
                                             df['Postcode range'][df.index[df['Abbreviation'] == abb].tolist()[0]])
        
        
        poscode_range = {key:[int(i) for i in val] for key, val in poscode_range.items()}
        
    return poscode_range

dict_poscode_range= scrapping_wikipedia('https://en.wikipedia.org/wiki/Postcodes_in_Australia')

# %%
# postcode range by state
dict_poscode_range
# Out:
# {'nsw': [1000, 1999, 2000, 2599, 2619, 2899, 2921, 2999],
#  'act': [200, 299, 2600, 2618, 2900, 2920],
#  'vic': [3000, 3999, 8000, 8999],
#  'qld': [4000, 4999, 9000, 9999],
#  'sa': [5000, 5799, 5800, 5999],
#  'wa': [6000, 6797, 6800, 6999],
#  'tas': [7000, 7799, 7800, 7999],
#  'nt': [800, 899, 900, 999]}

# %%
# load data suburb.csv
suburb = pd.read_csv("suburbs.csv")[['suburb', 'state']]
suburb['state'] = suburb['state'].str.lower()
suburb['suburb'] = suburb['suburb'].str.lower()

# suburb by state
dict_suburb = {}

for row in suburb['suburb'].unique():
    dict_suburb[row] = list(set(suburb[suburb.suburb == row]['state'].values.tolist()))

# %%
# give for each suburb the corresponding states
dict_suburb
# Out:
# {'east albury': ['nsw'],
#  'lavington': ['nsw'],
#  'glenroy': ['nsw', 'vic', 'qld', 'sa'],
#  'albury': ['nsw'],
#  'north albury': ['nsw'],
#  'table top': ['nsw'],
#  'splitters creek': ['nsw'],
#  'west albury': ['nsw'],
#  'springdale heights': ['nsw'],
#  'thurgoona': ['nsw'],
#  'south albury': ['nsw'],
#  'wirlinga': ['nsw'],
#  'hamilton valley': ['nsw'],
#  'jindera': ['nsw'],
#  'armidale': ['nsw'],
#  'boorolong': ['nsw'],
#  'dumaresq': ['nsw'],
#  'duval': ['nsw'],
#  'donald creek': ['nsw'],
#  'black mountain': ['nsw', 'qld'],
#  'aberfoyle': ['nsw'],
#  'thalgarrah': ['nsw'],
#  'wollomombi': ['nsw'],
#  'jeogla': ['nsw'],
#  'ebor': ['nsw'],
#  'dangarsleigh': ['nsw'],
#  'metz': ['nsw'],
#  'hillgrove': ['nsw'],
#  'castle doyle': ['nsw'],
#  'enmore': ['nsw'],
#  'lower creek': ['nsw'],
#  'carrai': ['nsw'],
#  'tilbuster': ['nsw'],
#  'kellys plains': ['nsw'],
#  'wongwibinda': ['nsw'],
#  'lyndhurst': ['nsw', 'vic', 'qld', 'sa'],
#  'puddledock': ['nsw'],
# ...

# %% [markdown]
# ### Forme des données

# %% [markdown]
# Le dataframe **_df_patient_** contient 20000 lignes et 12 colonnes ; on observe 3 types de données : objet, int64 et float64.
# Un premier aperçu nous montre déjà une incohérence entre la date de naissance et l'age. En effet, l'épidémie de COVID ayant dépbutée en fin 2019 début 2020, le patient _221958_ devrait avoir 49ans et non les 32ans donnés par la variable _age_. La partie EDA présentera une analyse de ces deux variables.
#
# Concernant le dataframe _**df_pcr**_, elle contient 8800 lignes et 2 colonnes. Le premier contient l'id du patient et le second le résultat du test pcr.

# %%
# overview
df_patient.head()
# Out:
#    patient_id given_name    surname  street_number            address_1  \
# 0      221958    matisse     clarke           13.0          rene street
# 1      771155     joshua     elrick           23.0         andrea place
# 2      231932      alice     conboy           35.0     mountain circuit
# 3      465838     sienna   craswell           39.0  cumberlegeicrescent
# 4      359178     joshua  bastiaans          144.0        lowrie street
#
#           suburb postcode state  date_of_birth   age phone_number address_2
# 0     ellenbrook     2527    wa     19710708.0  32.0  08 86018809  westella
# 1   east preston     2074   nsw     19120921.0  34.0  02 97793152   foxdown
# 2       prospect     2305   nsw     19810905.0  22.0  02 20403934      None
# 3          henty     3620    wa     19840809.0  30.0  02 62832318    jodane
# 4  campbell town     4051   nsw     19340430.0  31.0  03 69359594      None

# %%
# overview
df_pcr.head()
# Out:
#    patient_id       pcr
# 0      653091         N
# 1      347667  Negative
# 2      708481  Positive
# 3      148825  Negative
# 4      150081  Negative

# %%
df_pcr.shape
# Out:
# (8800, 2)

# %%
df_patient.shape
# Out:
# (20000, 12)

# %%
# check the data type of each column
df_patient.dtypes.value_counts().plot.pie()
plt.show()

# %% [markdown]
# ## Données manquantes

# %% [markdown]
# On observe que la variable _**address_2**_ comprend le plus de valeurs manquantes (> 60%). Pour les autres variables, le taux de valeurs manquantes est compris entre 20 et 1%, le mini étant pour la variable _**postcode**_. Sauf pour la variable patient_id qui ne comporte pas de données manquantes.

# %%
# Missing values
total = df_patient.isnull().sum().sort_values(ascending = False)
percent = round(total/df_patient.shape[0]*100 ,2)
pd.concat([total, percent], axis = 1, keys=["Total missing values","%"])
# Out:
#                Total missing values      %
# address_2                     12107  60.54
# age                            3997  19.98
# date_of_birth                  2011  10.06
# state                          1990   9.95
# phone_number                    919   4.60
# address_1                       796   3.98
# given_name                      440   2.20
# surname                         425   2.12
# street_number                   382   1.91
# suburb                          212   1.06
# postcode                        199   1.00
# patient_id                        0   0.00

# %% [markdown]
# ## Qualité des données

# %% [markdown]
# On observe que la variable **state** comporte plus de 8 modalités comme décrit au §I. En effet, elle compte 103 modalités. Un visualisation rapide nous permet de conclure à des erreurs de saisie.
#
# Pour les variables de type **'object'**, nous allons vérifier s'il existe des valeurs de type numérique.
# On observe alors que la variable **suburb**(banlieue) comporte 13 valeurs numériques. Pour la variable **postcode**(code postal), on observe l'existence de 14 valeurs textuelles.
#
# La visualisation des lignes montrant ces incohérences, nous permet de conclure que les valeurs ont été interverties.
#
# Pour le patient N° 727290, en plus de cette inversion, on constate une erreur de saisie au niveau du code postal (467l0). En effet, la lettre 'l' s'est glissée entre le 7 et le 0.
#
# La variable **phone_number** apparait comme étant constitué uniquement de valeurs textuelles. En effet, le format des valeurs (0X XXXXXXXX) ne permet pas de vérifier s'il s'agit de valeurs numériques ou textuelles. Un pré-traitement sera nécessaire si l'on souhaite utiliser cette variable.
#
# Pour la variable **patient_id**, qui devrait nous permettre de retrouver le résultat du test dans de la dataframe _df_pcr_, on observe qu certaines valeurs sont présentes plus d'une fois.
#
# Plus largement, on observe pour certains individus des incohérences entre les variables définissant la zone géographique (state, postcode, phone number, suburb).

# %%
df_patient_qlt = df_patient.copy()

# %%
# state
print(df_patient_qlt.state.unique())
print('Feature State, Number of modalities : {}'.format(len(df_patient_qlt.state.unique())))
# Out:
# ['wa' 'nsw' 'qld' 'nt' 'sa' None 'act' 'vic' 'tas' 'vc' 'qkd' 's' 'qlh'
#  'nswf' 'ndw' 'nsjw' 'nsza' 'nu' 'vicf' 'vicb' 'nswt' 'nsg' 'qlf' 'wr'
#  'vicz' 'nsa' 'wab' 'qxlj' 'ai' 'qlg' 'vil' 'qln' 'qlc' 'ws' 'qls' 'viv'
#  'ta' 'nswm' 'nfw' 'vie' 'nsq' 'nxw' 'nfsw' 'vkc' 'qlr' 'ns' 'naw' 'ic'
#  'nwd' 'qod' 'tab' 'nsd' 'vmv' 'fsw' 'vich' 'nwx' 'a' 'qlt' 'nsc' 'wu'
#  'nss' 'vucm' 'vix' 'nsy' 'ng' 'nse' 'w' 'ql' 'sv' 'taz' 'tak' 'vh' 'nze'
#  'nswb' 'qlz' 'vicm' 'waw' 'nsew' 'nvq' 'wz' 'gic' 'vid' 'qldg' 'vuv'
#  'vib' 'qud' 'nsxw' 'nlw' 'vif' 'nsn' 'nssw' 'nsgs' 'vicw' 'wq' 'vq'
#  'nswn' 'tad' 'qle' 'vcci' 'qdd' 'vi' 'qldy' 'nsjh']
# Feature State, Number of modalities : 103

# %%
def check_isdigit(df, feat):
    """
    This function check if a string is numeric or not
    """
    print(df[feat].str.isdigit().value_counts(), '\n')

# %%
# return the number of numeric value for each columns of dtypes 'object'
for feature in df_patient_qlt.dtypes[df_patient_qlt.dtypes == 'object'].index:
    check_isdigit(df_patient_qlt, feature)
# Out:
# False    19560
# Name: given_name, dtype: int64
#
# False    19575
# Name: surname, dtype: int64
#
# False    19204
# Name: address_1, dtype: int64
#
# False    19775
# True        13
# Name: suburb, dtype: int64
#
# True     19787
# False       14
# Name: postcode, dtype: int64
#
# False    18010
# Name: state, dtype: int64
#
# False    19081
# Name: phone_number, dtype: int64
#
# False    7893
# Name: address_2, dtype: int64

# %%
# columns : suburb. dataframe of inconsistent data
df_patient_qlt[df_patient_qlt.suburb.str.isdigit() == True]
# Out:
#        patient_id given_name        surname  street_number  \
# 3976       810644    juliana      grosvenor            5.0
# 4080       986559      kirra  choi-lundberg          102.0
# 5792       752873    lochlan          blake          258.0
# 6218       902348      isaac         nakoje           19.0
# 6618       678110      jaden          green            5.0
# 9653       690348     andrew           ryan           20.0
# 11333      738103       hugi         pascoe          167.0
# 14255      684359      sonia          green           50.0
# 15479      355033       abby           yoob          243.0
# 15575      572694   isabella        beddimg           17.0
# 18658      132735     jairys           dent            2.0
# 18784      241868       elly           webb          195.0
# 19150      674065   nichalas          mason           74.0
#
#                      address_1 suburb              postcode state  \
# 3976             connelly pace   3023  port noarlunga south   tas
# ...

# %%
# columns : postcode. dataframe of inconsistent data
df_patient_qlt[df_patient_qlt.postcode.str.isdigit() == False]
# Out:
#        patient_id given_name        surname  street_number  \
# 3976       810644    juliana      grosvenor            5.0
# 4080       986559      kirra  choi-lundberg          102.0
# 5792       752873    lochlan          blake          258.0
# 6218       902348      isaac         nakoje           19.0
# 6618       678110      jaden          green            5.0
# 9653       690348     andrew           ryan           20.0
# 9718       727290    tiffany         loukes           31.0
# 11333      738103       hugi         pascoe          167.0
# 14255      684359      sonia          green           50.0
# 15479      355033       abby           yoob          243.0
# 15575      572694   isabella        beddimg           17.0
# 18658      132735     jairys           dent            2.0
# 18784      241868       elly           webb          195.0
# 19150      674065   nichalas          mason           74.0
#
#                      address_1 suburb              postcode state  \
# ...

# %%
df_patient_qlt.patient_id.value_counts()
# Out:
# 428821    3
# 378910    2
# 805191    2
# 461417    2
# 517216    2
#          ..
# 578720    1
# 482465    1
# 831616    1
# 961596    1
# 200706    1
# Name: patient_id, Length: 19798, dtype: int64

# %% [markdown]
# ## Gestion des doublons

# %% [markdown]
# Le but de cette exercice étant de représenter et de discuter la prévalence de la maladie dans la population et non à des fins de prédiction, on peut alors ignorer les individus dont le patient_id n'est pas présent dans le dataframe _**df_pcr**_. Ce premier filtre permet de constater que le taux de données manquantes est identique entre le dataframe à 20000 lignes (df_patient initial) et le dataframe à 8800 lignes (df_patient après suppression des patient_id non présentent dans le dataframe df_pcr).
#
# La méthode d'identification des doublons retenue ici passe par l'évaluation de la qualité des variables. Pour cela, on se concentre principalement sur les variables liées à la zone géographique, à savoir : state, phone number, suburb, postcode. Ainsi pour chaque patient, on va effectuer pour la variable:
# - **State** : Un nettoyage pour se ramener à 1 des 8 états. Pour cela nous allons appliquer une recherche de correspondance pour chaque valeur de la colonne avec l'abbréviation réelle des états.
# - **Phone number**: On va récuperer le code de la zone et en déduire la/les états correspondant.
# - **Suburb**: On effectue la correspondance avec le dictionnaire _dict_suburb_.
# - **Postcode**: On effectue la correspondance avec le dictionnaire _dict_poscode_range_ fournissant les plages en fontion des états.
#
# Ces opérations permettent de résumer les informations portées par ces variables autour de la zone géographique (l'état). Ainsi, pour chaque individu on évalue l'occurance de chaque état auquelle on applique une pondération. La pondération provient de l'évaluation du taux de patient par état en partant de la variable présentant le moins de données manquantes, à savoir _post_code_.
#
# Cette méthode va non seulement permettre d'identifier l'état le plus probable. Mais aussi, pour des  patients présentant le même patient_id récupérer celui présentant la plus grande probabilité d'appartenir à un état parmis ces candidats.

# %%
def match_postcode(df):
    """
    This function return the state for given postcode.
    """
    
    if df['postcode'] is None:
        return None
    else:
        for ps_state in dict_poscode_range.keys():
            groups= list(zip(*[iter(dict_poscode_range[ps_state])]*2))
            if any(start <= int(df['postcode']) <= end for start,end in groups):
                return ps_state

# %%
def weight_states(df):
    """
    This functions return the weight by state.
    """
    # index of wrong column values  
    idx_swap = df[df.postcode.str.isdigit() == False].index.tolist()
    
    # swap wrong columns
    df.loc[idx_swap, ['suburb', 'postcode']] = df.loc[idx_swap, ['postcode', 
                                                                 'suburb']].values
    
    # find the string value in column postcode
    idx_str = df[df.postcode.str.isdigit() == False]['postcode'].index.values[0]
    
    
    # from string to int
    df.at[idx_str, 'postcode'] = int(''.join(re.findall(r'[0-9]+', 
                                                        df.at[idx_str,'postcode'])))
    
    
    # from postcode to state
    df['postcode_cln'] = df.apply(match_postcode, axis= 1)
    
    # percent of patients by state from postcode value
    percent = df.postcode_cln.value_counts()/df.postcode_cln.value_counts().sum()
    
    return percent.to_dict()

df_patient_wgt = df_patient.copy()
wgt = weight_states(df_patient_wgt)
wgt
# Out:
# {'nsw': 0.3362460854631781,
#  'vic': 0.24679260531366803,
#  'qld': 0.1912314375189413,
#  'wa': 0.09283766036973432,
#  'sa': 0.07879583796343065,
#  'tas': 0.026618850388928174,
#  'act': 0.018537225982422467,
#  'nt': 0.008940296999696938}

# %%
df_patient_dbl = df_patient.copy()

# %%
# Missing values and gap between df_patient init
total_2 = df_patient_dbl.isnull().sum().sort_values(ascending = False)
percent_2 = round(total_2/df_patient_dbl.shape[0]*100 ,2)
dif = percent - percent_2
pd.concat([total_2, percent_2, dif], axis = 1, keys=["Total missing values","%", "Gap"])
# Out:
#                Total missing values      %  Gap
# address_2                     12107  60.54  0.0
# age                            3997  19.98  0.0
# date_of_birth                  2011  10.06  0.0
# state                          1990   9.95  0.0
# phone_number                    919   4.60  0.0
# address_1                       796   3.98  0.0
# given_name                      440   2.20  0.0
# surname                         425   2.12  0.0
# street_number                   382   1.91  0.0
# suburb                          212   1.06  0.0
# postcode                        199   1.00  0.0
# patient_id                        0   0.00  0.0

# %%
def state_data_cleaning(df):
    """ 
    This function return the right state's name. 
    """
    
    
    # not right state names
    dict_others_states = {}
    
    # states in the dataframe
    states = df_patient.state.value_counts().index
    
    # for each states check the most correspondance in dict_state.
    for st in states:
        if st not in dict_state.keys():
            dict_others_states[st] = difflib.get_close_matches(st, 
                                                                  dict_state.keys(),
                                                                 cutoff=0.3)[0]
    # edit dataframe columns state
    if df['state'] in dict_state.keys():
        return df['state']
    elif df['state'] is None:
        return None
    else:
        return dict_others_states[df['state']]

def zone_name(df):
    """
    The function return the states fo each area zone
    """
    if df['area_zone'] in dict_phone_number.keys():
        return dict_phone_number[df['area_zone']]
    else:
        return None


def match_suburb(df):
    """
    This function return the states fo each suburb
    """
    if df['suburb'] is None:
        return None
    elif df['suburb'] in dict_suburb.keys():
        return ' '.join(dict_suburb[df['suburb']])
    else:
        return None
    
    
def detect_duplicates(df):
    """
    This function detect duplicated patient
    """
    
    # get unique patient_id in the dataframe df_pcr
    df_pcr_unique = df_pcr.patient_id.unique()
    
    # subset rows in dataframe df_patient
    df_dpt = df[df.patient_id.isin(df_pcr_unique)]
    
    # get duplicated patient_id
    dpt_patient_id= []
    for id_patient in df_pcr_unique:
        if len(df_dpt[df_dpt.patient_id == id_patient]) > 1:
            dpt_patient_id.append(id_patient)
    
    # list of duplacate index
    idx_drop = []
    
    
    # for each patient_id duplicated
    for row in dpt_patient_id:
        check_right = df_dpt[df_dpt.patient_id == row][['patient_id',
                                                        'address_1', 
                                                        'suburb', 
                                                        'postcode',
                                                        'state', 
                                                        'phone_number']]
        
        # add columns state cleaning
        check_right['state_cln'] = check_right.apply(state_data_cleaning, axis= 1)
        
        # add columns area zone (phone number)
        check_right['area_zone'] = check_right.phone_number.str.extract(r'([^\s]+)')
        
        # add columns name zone area 
        check_right['area_zone_cln'] = check_right.apply(zone_name, axis= 1)
        check_right.drop(columns= ['area_zone'], axis= 1, inplace= True)
        
        # check the postcode and give the state correspond
        check_right['poscode_cln'] = check_right.apply(match_postcode, axis= 1)
        
        # check the suburb and give the state correspond
        check_right['suburb_cln'] = check_right.apply(match_suburb, axis= 1)
        
        # dictionnary for idx et state max.
        dict_max_idx = {}
        dict_max_state = {}
        
        for row in range(len(check_right)):
            # list of states for each row 
            list_state = ' '.join([i for i 
                                   in check_right.iloc[row]['state_cln': 
                                                            'suburb_cln'].values.tolist() if i]).split(' ')
            
            # occurance for each state in the list 
            count = dict(Counter(list_state))
            
            # add weight to count.
            for cnt in count.keys():
                count[cnt] = count[cnt]*wgt[cnt]
            
            # find index of max ans the state.
            dict_max_idx[check_right.index[row]] = max(count, key=count.get)
            dict_max_state[check_right.index[row]] = max(count.values())
            
            
        # add the index of row to drop    
        idx_drop.append(min(dict_max_state, key=dict_max_state.get))
    
    # drop duplicated rows
    df_dpt.drop(idx_drop, inplace= True)
        

    return df_dpt

# %%
df_patient_drop = detect_duplicates(df_patient_dbl)
# Out:
# /Users/pierrebz/opt/anaconda3/envs/aphp/lib/python3.7/site-packages/pandas/core/frame.py:4164: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_patient_drop
# Out:
#        patient_id given_name      surname  street_number          address_1  \
# 1          771155     joshua       elrick           23.0       andrea place
# 5          744167         ky        laing          448.0        nyawi place
# 6          210268    matthew        laing           11.0       barnes place
# 7          832180       jack      renfrey           27.0      osmand street
# 8          154886      adele         ryan           76.0      house circuit
# ...           ...        ...          ...            ...                ...
# 19983      230775   victoria     whiteley           12.0     beasley street
# 19985      407822      sarah     matthews           58.0        zox circuit
# 19989      704579    michael     eglinton          215.0  ambalindum street
# 19992      329489      amber  leeuwenburg           50.0               None
# 19993      506906     cooper     sherriff           25.0    monaro crescent
#
# ...

# %%
print('On observe {}% \
de données dupliquées'.format(round(100 - df_patient_drop.shape[0]/df_patient.shape[0]*100, 2)))
# Out:
# On observe 56.18% de données dupliquées

# %% [markdown]
# ### Test

# %% [markdown]
# ## Jointure avec df_pcr

# %% [markdown]
# La jointure est effectuée en utilisant le dataframe après suppression des doublons. Le dataframe df_pcr contenant des patient_id en double on va se retrouver face à des indohérences, notamment si pour un même patient_id on a deux résultats différents.
#
# On vérifie alors pour chaque patient_id en double, si le résultat est identique. Si oui on ne garde qu'un seul index, si non on supprimer les 2 index et donc le patient_id.
#
# De plus, on ajoute une colonne **Finale_State** qui permet de résumer l'information portait par les colonnes : states, postcode, suburb et phone number. Pour cela on applique la même qui y'a permis de  supprimer les doublons mais cette fois ci on cherche l'état le plus probable.

# %%
dataset = df_patient_drop.merge(df_pcr)

# %%
df_patient_pcr = dataset.copy()

# %%
def encoding_pcr(df):
    """
    This function encode the column pcr
    """
    if df['pcr'] == 'N':
        return 'Negative'
    elif df['pcr'] == 'P':
        return 'Positive'
    else:
        return df['pcr']

# %%
df_patient_pcr['Test'] = df_patient_pcr.apply(encoding_pcr, axis= 1)
df_patient_pcr.drop(['pcr'], axis= 1, inplace= True)

# %%
# add columns state cleaning
df_patient_pcr['state_cln'] = df_patient_pcr.apply(state_data_cleaning, axis= 1)

# add columns area zone (phone number)
df_patient_pcr['area_zone'] = df_patient_pcr.phone_number.str.extract(r'([^\s]+)')

# add columns name zone area 
df_patient_pcr['area_zone_cln'] = df_patient_pcr.apply(zone_name, axis= 1)
df_patient_pcr.drop(columns= ['area_zone'], axis= 1, inplace= True)

# index of wrong column values  
idx_swap_pcr = df_patient_pcr[df_patient_pcr.postcode.str.isdigit() == False].index.tolist()

# swap wrong columns
df_patient_pcr.loc[idx_swap_pcr, ['suburb', 'postcode']] = df_patient_pcr.loc[
    idx_swap_pcr, ['postcode','suburb']].values

# check the postcode and give the state correspond
df_patient_pcr['poscode_cln'] = df_patient_pcr.apply(match_postcode, axis= 1)

# check the suburb and give the state correspond
df_patient_pcr['suburb_cln'] = df_patient_pcr.apply(match_suburb, axis= 1)


max_state_wgt = []

for row in range(len(df_patient_pcr)):
    list_state = ' '.join([i for i 
                           in df_patient_pcr.iloc[row]['state_cln': 
                                                    'suburb_cln'].values.tolist() if i]).split(' ')
    count = dict(Counter(list_state))
    
    for cnt in count.keys():
        count[cnt] = count[cnt]*wgt[cnt]
        
    max_state_wgt.append(max(count, key=count.get))

df_patient_pcr['Final_State'] = max_state_wgt

# %%
df_patient_pcr.shape
# Out:
# (8800, 18)

# %%
def drop_dpt_pcr(df):
    """
    """
    drop_ixd = []
    
    # get duplicated patient_id
    dpt_patient_id= []
    for id_patient in df.patient_id.unique():
        if len(df[df.patient_id == id_patient]) > 1:
            dpt_patient_id.append(id_patient)
    
    for row in dpt_patient_id:
        check_df = df[df.patient_id == row]
        if check_df.iloc[0, df.columns.get_loc('Test')] != check_df.iloc[0, df.columns.get_loc('Test')]:
            drop_ixd.extend(check_df.index.tolist())
        else:
            drop_ixd.extend([check_df.index.tolist()[0]])
    
    return drop_ixd

# %%
drop_idx_pcr = drop_dpt_pcr(df_patient_pcr)
df_patient_pcr.drop(drop_idx_pcr, inplace=True)

# %%
df_patient_pcr.shape
# Out:
# (8765, 18)

# %%
df_patient_pcr.head()
# Out:
#    patient_id given_name  surname  street_number      address_1        suburb  \
# 0      771155     joshua   elrick           23.0   andrea place  east preston
# 1      744167         ky    laing          448.0    nyawi place       barmera
# 2      210268    matthew    laing           11.0   barnes place     laurieton
# 3      832180       jack  renfrey           27.0  osmand street   maribyrnong
# 4      154886      adele     ryan           76.0  house circuit      new farm
#
#   postcode state  date_of_birth   age phone_number    address_2      Test  \
# 0     2074   nsw     19120921.0  34.0  02 97793152      foxdown  Negative
# 1     3556   qld     19050919.0  32.0  03 59872070         None  Negative
# 2     2160   nsw     19061018.0  29.0  02 86925029         None  Negative
# 3     2170   qld     19610518.0  31.0  03 15575583  dhurringill  Positive
# 4     2200   qld     19430102.0  33.0  07 37444521         None  Negative
#
# ...

# %% [markdown]
# ## EDA

# %%
df_patient_eda = df_patient_pcr.copy()

# %%
df_patient_eda['date_of_birth'] = df_patient_eda['date_of_birth'].astype(str) 

df_patient_eda['age_date'] = df_patient_eda['date_of_birth'].str.extract(r'(^\w{4})')

df_patient_eda['age_date'] = 2020 - pd.to_numeric(df_patient_eda['age_date'])

# %%
df_patient_eda.head()
# Out:
#    patient_id given_name  surname  street_number      address_1        suburb  \
# 0      771155     joshua   elrick           23.0   andrea place  east preston
# 1      744167         ky    laing          448.0    nyawi place       barmera
# 2      210268    matthew    laing           11.0   barnes place     laurieton
# 3      832180       jack  renfrey           27.0  osmand street   maribyrnong
# 4      154886      adele     ryan           76.0  house circuit      new farm
#
#   postcode state date_of_birth   age phone_number    address_2      Test  \
# 0     2074   nsw    19120921.0  34.0  02 97793152      foxdown  Negative
# 1     3556   qld    19050919.0  32.0  03 59872070         None  Negative
# 2     2160   nsw    19061018.0  29.0  02 86925029         None  Negative
# 3     2170   qld    19610518.0  31.0  03 15575583  dhurringill  Positive
# 4     2200   qld    19430102.0  33.0  07 37444521         None  Negative
#
# ...

# %%
# check
df_patient_eda.Test.value_counts().plot.pie()
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(221)
sns.boxplot(df_patient_eda.age,orient= 'v')
ax = fig.add_subplot(222)
sns.boxplot(df_patient_eda.age_date,orient= 'v')
plt.show()

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(221)
sns.distplot(df_patient_eda.age, bins= 50)
ax = fig.add_subplot(222)
sns.distplot(df_patient_eda.age_date, bins= 50)
plt.show()

# %%
feat_plt = ['state_cln', 'area_zone_cln', 'poscode_cln', 'Final_State']
for row in feat_plt:
    fig = plt.figure(figsize=(10,8))
    sns.countplot(x=row, hue='Test', data=df_patient_eda)
    plt.show()

# %% [markdown]
# ## Conclusion
